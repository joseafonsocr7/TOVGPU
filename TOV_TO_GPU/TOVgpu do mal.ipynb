# %%
##Google colab
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/My Drive/TOV_TO_GPU')
# Out:
# Mounted at /content/drive

# %%
##GPU
from tovgpu import TOVGPU
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-fcfaa34db6d5> in <cell line: 0>()
#       1 ##GPU
# ----> 2 from tovgpu import TOVGPU
#
# /content/drive/My Drive/TOV_TO_GPU/tovgpu.py in <module>
#     383 solver = TOVGPU(en_arr, p_arr)
#     384 for i in range(10):
# --> 385     R, M, profile = solver.solve(central_densities[i])
#     386     R_arr[i] = R
#     387     M_arr[i] = M
#
# /content/drive/My Drive/TOV_TO_GPU/tovgpu.py in solve(self, c_dens, rmax, rtol, dmrel, dr)
#     285     m = 4.0 * pi * r[0] ** 3 * eden
#     286
# --> 287     psol = TOVGPU.odeint(self.tov_eq, [P, m], r, rtol=rtol)
#     288
#     289     p_R, m_R = psol[:,0], psol[:,1]
#
# /content/drive/My Drive/TOV_TO_GPU/tovgpu.py in odeint(f, y0, t, args, rtol)
#      16     t = cp.asarray(t, dtype=cp.float64)
#      17     y = cp.zeros((len(t), len(y0)), dtype=cp.float64)
# ...

# %%
##CPU
from tov import TOV
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 45005 Iterações
# 45006 Iterações
# 45007 Iterações
# 45008 Iterações
# 45009 Iterações
# 45010 Iterações
# 45011 Iterações
# 45012 Iterações
# 45013 Iterações
# 45014 Iterações
# 45015 Iterações
# 45016 Iterações
# 45017 Iterações
# 45018 Iterações
# 45019 Iterações
# 45020 Iterações
# 45021 Iterações
# 45022 Iterações
# 45023 Iterações
# 45024 Iterações
# 45025 Iterações
# 45026 Iterações
# 45027 Iterações
# 45028 Iterações
# 45029 Iterações
# 45030 Iterações
# 45031 Iterações
# 45032 Iterações
# 45033 Iterações
# 45034 Iterações
# 45035 Iterações
# 45036 Iterações
# 45037 Iterações
# 45038 Iterações
# 45039 Iterações
# 45040 Iterações
# 45041 Iterações
# 45042 Iterações
# 45043 Iterações
# 45044 Iterações
# 45045 Iterações
# 45046 Iterações
# 45047 Iterações
# 45048 Iterações
# 45049 Iterações
# 45050 Iterações
# 45051 Iterações
# 45052 Iterações
# 45053 Iterações
# 45054 Iterações
# 45055 Iterações
# 45056 Iterações
# ...
